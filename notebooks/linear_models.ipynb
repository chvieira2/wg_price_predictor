# %% [markdown]
# # Load ads

# %%
import requests
import io
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'. Needed to remove SettingWithCopyWarning warning when assigning new value to dataframe column
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

import statsmodels.formula.api as smf
import statsmodels.api as sm

# %load_ext autoreload
# %autoreload 2

# from housing_crawler.utils import save_file, get_file, get_grid_polygons_all_cities
# from housing_crawler.analysis.ads_table_processing import get_processed_ads_table
# from housing_crawler.string_utils import remove_prefix, simplify_address, standardize_characters, capitalize_city_name, german_characters
# from housing_crawler.utils import standardize_features, return_significative_coef


# from wg_price_predictor.config import ROOT_DIR
# from housing_crawler.params import dict_city_number_wggesucht
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
### Main dataframe
# ads_OSM.csv is the product of running get_processed_ads_table() in ads_table_processing.py in housing_crawler
monthly = []
for month in ['07','08','09','10','11','12']:
    download = requests.get(f'https://raw.githubusercontent.com/chvieira2/housing_crawler/master/raw_data/2022{month}_ads_OSM.csv').content
    monthly.append(pd.read_csv(io.StringIO(download.decode('utf-8'))))
    del month

df_original = pd.concat(monthly)
del monthly
ads_feat_df = df_original#[~pd.isnull(df_original[target])]
list(ads_feat_df.columns)
# Out:
# /tmp/ipykernel_21253/1307428562.py:6: DtypeWarning: Columns (29,31,33,34,35,37,42,46,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   monthly.append(pd.read_csv(io.StringIO(download.decode('utf-8'))))
# /tmp/ipykernel_21253/1307428562.py:6: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   monthly.append(pd.read_csv(io.StringIO(download.decode('utf-8'))))
# /tmp/ipykernel_21253/1307428562.py:6: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   monthly.append(pd.read_csv(io.StringIO(download.decode('utf-8'))))
# /tmp/ipykernel_21253/1307428562.py:6: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   monthly.append(pd.read_csv(io.StringIO(download.decode('utf-8'))))
# /tmp/ipykernel_21253/1307428562.py:6: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   monthly.append(pd.read_csv(io.StringIO(download.decode('utf-8'))))
# /tmp/ipykernel_21253/1307428562.py:6: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   monthly.append(pd.read_csv(io.StringIO(download.decode('utf-8'))))
# ['id',
#  'url',
#  'commercial_landlord',
#  'title',
#  'price_euros',
#  'size_sqm',
#  'available_rooms',
#  'capacity',
#  'available_spots_wg',
#  'male_flatmates',
#  'female_flatmates',
#  'diverse_flatmates',
#  'published_on',
#  'published_at',
#  'address',
#  'city',
#  'crawler',
#  'latitude',
#  'longitude',
#  'available_from',
#  'available_to',
#  'details_searched',
#  'cold_rent_euros',
#  'mandatory_costs_euros',
#  'extra_costs_euros',
#  'transfer_costs_euros',
#  'deposit',
#  'zip_code',
#  'home_total_size',
#  'smoking',
#  'wg_possible',
#  'building_type',
#  'building_floor',
#  'furniture',
#  'kitchen',
#  'heating',
#  'public_transport_distance',
#  'parking',
#  'schufa_needed',
#  'type_offer_simple',
#  'min_age_flatmates',
#  'max_age_flatmates',
#  'gender_searched',
#  'min_age_searched',
#  'max_age_searched',
#  'construction_year',
#  'energy_certificate',
#  'energy_usage',
#  'energy_efficiency_class',
#  'heating_energy_source',
#  'price_per_sqm_warm',
#  'price_per_sqm_cold',
#  'number_languages',
#  'internet_speed',
#  'toilet',
#  'internet_dsl',
#  'internet_wlan',
#  'internet_flatrate',
#  'shower_type_badewanne',
#  'shower_type_dusche',
#  'floor_type_dielen',
#  'floor_type_parkett',
#  'floor_type_laminat',
#  'floor_type_teppich',
#  'floor_type_fliesen',
#  'floor_type_pvc',
#  'floor_type_fußbodenheizung',
#  'extras_waschmaschine',
#  'extras_spuelmaschine',
#  'extras_terrasse',
#  'extras_balkon',
#  'extras_garten',
#  'extras_gartenmitbenutzung',
#  'extras_keller',
#  'extras_aufzug',
#  'extras_haustiere',
#  'extras_fahrradkeller',
#  'extras_dachboden',
#  'languages_deutsch',
#  'languages_englisch',
#  'wg_type_studenten',
#  'wg_type_keine_zweck',
#  'wg_type_maenner',
#  'wg_type_business',
#  'wg_type_wohnheim',
#  'wg_type_vegetarisch_vegan',
#  'wg_type_alleinerziehende',
#  'wg_type_funktionale',
#  'wg_type_berufstaetigen',
#  'wg_type_gemischte',
#  'wg_type_mit_kindern',
#  'wg_type_verbindung',
#  'wg_type_lgbtqia',
#  'wg_type_senioren',
#  'wg_type_inklusive',
#  'wg_type_wg_neugruendung',
#  'tv_kabel',
#  'tv_satellit',
#  'day_of_week_publication',
#  'days_available',
#  'rental_length_term',
#  'furniture_numerical',
#  'kitchen_numerical',
#  'smoking_numerical',
#  'age_category_searched',
#  'room_size_house_fraction',
#  'flat_with_kids',
#  'km_to_centroid',
#  'comfort_leisure_spots',
#  'comfort_warehouse',
#  'activities_education',
#  'mobility_public_transport_bus',
#  'activities_economic',
#  'comfort_industrial',
#  'activities_goverment',
#  'social_life_eating',
#  'comfort_comfort_spots',
#  'social_life_culture',
#  'activities_supermarket',
#  'activities_public_service',
#  'social_life_community',
#  'comfort_leisure_mass',
#  'activities_educational',
#  'mobility_street_secondary',
#  'mobility_public_transport_rail',
#  'activities_retail',
#  'social_life_night_life',
#  'comfort_green_natural',
#  'comfort_railway',
#  'mobility_bike_infraestructure',
#  'comfort_green_forests',
#  'mobility_street_primary',
#  'comfort_lakes',
#  'activities_health_regional',
#  'activities_health_local',
#  'comfort_green_space',
#  'comfort_rivers',
#  'activities_post',
#  'comfort_green_parks',
#  'comfort_street_motorway',
#  'sin_degrees_to_centroid',
#  'cos_degrees_to_centroid',
#  'sin_published_at',
#  'cos_published_at',
#  'sin_day_week_int',
#  'cos_day_week_int']

# %%
# Number of duplicate data points
# It's very likely zero cause I already removed dulicated IDs during processing
ads_feat_df.duplicated().sum()
# Out:
# 0

# %%
# Percentage missing values per column
round(ads_feat_df.isnull().sum().sort_values(ascending=False)/len(ads_feat_df)*100,1)[0:30]
# Out:
# energy_usage                      94.9
# energy_efficiency_class           93.4
# toilet                            91.4
# construction_year                 86.6
# internet_speed                    81.6
# kitchen                           78.2
# max_age_flatmates                 61.4
# min_age_flatmates                 58.4
# smoking                           58.1
# social_life_community             50.5
# activities_education              50.5
# comfort_warehouse                 50.5
# comfort_leisure_spots             50.5
# km_to_centroid                    50.5
# activities_supermarket            50.5
# social_life_night_life            50.5
# activities_economic               50.5
# activities_educational            50.5
# mobility_street_secondary         50.5
# mobility_public_transport_rail    50.5
# activities_public_service         50.5
# activities_retail                 50.5
# mobility_public_transport_bus     50.5
# comfort_leisure_mass              50.5
# comfort_industrial                50.5
# activities_health_regional        50.5
# social_life_culture               50.5
# comfort_comfort_spots             50.5
# social_life_eating                50.5
# cos_degrees_to_centroid           50.5
# dtype: float64

# %% [markdown]
# # Creating WG, single-room and multi-room dataframes

# %%
wg_df = ads_feat_df.query('type_offer_simple == "WG"').reset_index().drop(columns=['index'])

singleroom_df = ads_feat_df.query('type_offer_simple == "Single-room flat"').reset_index().drop(columns=['index'])

flathouse_df = ads_feat_df.query('(type_offer_simple == "Apartment")').reset_index().drop(columns=['index'])

# %% [markdown]
# # Linear model WG

# %%
wg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42722 entries, 0 to 42721
# Columns: 146 entries, id to cos_day_week_int
# dtypes: float64(122), int64(3), object(21)
# memory usage: 47.6+ MB

# %%
# define columns to work
features = [
    'km_to_centroid',
    'sin_degrees_to_centroid',
    'cos_degrees_to_centroid',
    
    'comfort_leisure_spots',
    'comfort_warehouse',
    'activities_education',
    'mobility_public_transport_bus',
    'activities_economic',
    'comfort_industrial',
    'activities_goverment',
    'social_life_eating',
    'comfort_comfort_spots',
    'social_life_culture',
    'activities_supermarket',
##     'activities_public_service',
    'social_life_community',
    'comfort_leisure_mass',
    'activities_educational',
    'mobility_street_secondary',
    'mobility_public_transport_rail',
    'activities_retail',
    'social_life_night_life',
    'comfort_green_natural',
    'comfort_railway',
    'mobility_bike_infraestructure',
##     'comfort_green_forests',
    'mobility_street_primary',
    'comfort_lakes',
##     'activities_health_regional',
    'activities_health_local',
    'comfort_green_space',
    'comfort_rivers',
    'activities_post',
    'comfort_green_parks',
    'comfort_street_motorway'
]

target = 'cold_rent_euros'#'price_per_sqm'

selected_num_features = [
            'size_sqm',
#         'home_total_size',
#         'available_rooms',
        'capacity',
#         'available_spots_wg',

        'days_available',
#         'sin_published_at',
#         'cos_published_at',
        'sin_day_week_int',
        'cos_day_week_int',
    
# Values
#         'cold_rent_euros',
#         'mandatory_costs_euros',
#         'extra_costs_euros',
#         'deposit',
#         'transfer_costs_euros',
#         'price_per_sqm',

# Flatmates
        'male_flatmates',
        'female_flatmates',
        'diverse_flatmates',
#         'min_age_flatmates',
#         'max_age_flatmates',
    
# Person searched
        'min_age_searched',
        'max_age_searched',
    
# Details
    
        'smoking_numerical',
        'furniture_numerical',
#       'kitchen_numerical',
        'public_transport_distance',

    
# WG only
        'number_languages',
        
#         'internet_speed',
    
] + features
selected_cat_features = ['city',
                         'commercial_landlord',
            
        'rental_length_term',
    
# Person searched
        'gender_searched',
        'age_category_searched',
    
# Details
    
        'schufa_needed',
#         'wg_possible',
    
#         'smoking',
        'building_type',
        'building_floor',
#         'furniture',
#         'kitchen',
#         'heating',
#         'parking',
    
        'tv_kabel',
        'tv_satellit',
    
        'shower_type_badewanne',
        'shower_type_dusche',
    
        'floor_type_dielen',
        'floor_type_parkett',
        'floor_type_laminat',
        'floor_type_teppich',
        'floor_type_fliesen',
        'floor_type_pvc',
        'floor_type_fußbodenheizung',
    
        'extras_waschmaschine',
        'extras_spuelmaschine',
        'extras_terrasse',
        'extras_balkon',
        'extras_garten',
#         'extras_gartenmitbenutzung',
        'extras_keller',
        'extras_aufzug',
        'extras_haustiere',
        'extras_fahrradkeller',
        'extras_dachboden',
    
# WG only
        'languages_deutsch',
        'languages_englisch',
    
        'wg_type_studenten',
        'wg_type_keine_zweck',
        'wg_type_maenner',
        'wg_type_business',
        'wg_type_wohnheim',
        'wg_type_vegetarisch_vegan',
        'wg_type_alleinerziehende',
        'wg_type_funktionale',
        'wg_type_berufstaetigen',
        'wg_type_gemischte',
        'wg_type_mit_kindern',
        'wg_type_verbindung',
        'wg_type_lgbtqia',
        'wg_type_senioren',
        'wg_type_inklusive',
        'wg_type_wg_neugruendung',
    
        'internet_dsl',
        'internet_wlan',
        'internet_flatrate'
                        ]
all_columns = [target] + selected_num_features + selected_cat_features

columns_to_zscore = selected_num_features


# Filter dataframe for modelling
df_zscored = wg_df[all_columns#+['city']
                     ].copy()

df_zscored.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42722 entries, 0 to 42721
# Data columns (total 97 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   cold_rent_euros                 40068 non-null  float64
#  1   size_sqm                        42722 non-null  float64
#  2   capacity                        42722 non-null  float64
#  3   days_available                  42722 non-null  int64
#  4   sin_day_week_int                42722 non-null  float64
#  5   cos_day_week_int                42722 non-null  float64
#  6   male_flatmates                  42722 non-null  float64
#  7   female_flatmates                42722 non-null  float64
#  8   diverse_flatmates               42722 non-null  float64
#  9   min_age_searched                42718 non-null  float64
#  10  max_age_searched                42718 non-null  float64
#  11  smoking_numerical               42718 non-null  float64
#  12  furniture_numerical             42718 non-null  float64
#  13  public_transport_distance       38654 non-null  float64
#  14  number_languages                42718 non-null  float64
#  15  km_to_centroid                  20970 non-null  float64
#  16  sin_degrees_to_centroid         20970 non-null  float64
#  17  cos_degrees_to_centroid         20970 non-null  float64
#  18  comfort_leisure_spots           20970 non-null  float64
#  19  comfort_warehouse               20970 non-null  float64
#  20  activities_education            20970 non-null  float64
#  21  mobility_public_transport_bus   20970 non-null  float64
#  22  activities_economic             20970 non-null  float64
#  23  comfort_industrial              20970 non-null  float64
#  24  activities_goverment            20970 non-null  float64
#  25  social_life_eating              20970 non-null  float64
#  26  comfort_comfort_spots           20970 non-null  float64
#  27  social_life_culture             20970 non-null  float64
#  28  activities_supermarket          20970 non-null  float64
#  29  social_life_community           20970 non-null  float64
#  30  comfort_leisure_mass            20970 non-null  float64
#  31  activities_educational          20970 non-null  float64
#  32  mobility_street_secondary       20970 non-null  float64
#  33  mobility_public_transport_rail  20970 non-null  float64
#  34  activities_retail               20970 non-null  float64
#  35  social_life_night_life          20970 non-null  float64
#  36  comfort_green_natural           20970 non-null  float64
#  37  comfort_railway                 20970 non-null  float64
#  38  mobility_bike_infraestructure   20970 non-null  float64
#  39  mobility_street_primary         20970 non-null  float64
#  40  comfort_lakes                   20970 non-null  float64
#  41  activities_health_local         20970 non-null  float64
#  42  comfort_green_space             20970 non-null  float64
#  43  comfort_rivers                  20970 non-null  float64
#  44  activities_post                 20970 non-null  float64
#  45  comfort_green_parks             20970 non-null  float64
#  46  comfort_street_motorway         20970 non-null  float64
#  47  city                            42722 non-null  object
#  48  commercial_landlord             42722 non-null  float64
#  49  rental_length_term              42722 non-null  object
#  50  gender_searched                 42718 non-null  object
#  51  age_category_searched           42722 non-null  object
#  52  schufa_needed                   42718 non-null  float64
#  53  building_type                   42718 non-null  object
#  54  building_floor                  39218 non-null  float64
#  55  tv_kabel                        42718 non-null  float64
#  56  tv_satellit                     42718 non-null  float64
#  57  shower_type_badewanne           42718 non-null  float64
#  58  shower_type_dusche              42718 non-null  float64
#  59  floor_type_dielen               42718 non-null  float64
#  60  floor_type_parkett              42718 non-null  float64
#  61  floor_type_laminat              42718 non-null  float64
#  62  floor_type_teppich              42718 non-null  float64
#  63  floor_type_fliesen              42718 non-null  float64
#  64  floor_type_pvc                  42718 non-null  float64
#  65  floor_type_fußbodenheizung      42718 non-null  float64
#  66  extras_waschmaschine            42718 non-null  float64
#  67  extras_spuelmaschine            42718 non-null  float64
#  68  extras_terrasse                 42718 non-null  float64
#  69  extras_balkon                   42718 non-null  float64
#  70  extras_garten                   42718 non-null  float64
#  71  extras_keller                   42718 non-null  float64
#  72  extras_aufzug                   42718 non-null  float64
#  73  extras_haustiere                42718 non-null  float64
#  74  extras_fahrradkeller            42718 non-null  float64
#  75  extras_dachboden                42718 non-null  float64
#  76  languages_deutsch               42718 non-null  float64
#  77  languages_englisch              42718 non-null  float64
#  78  wg_type_studenten               42718 non-null  float64
#  79  wg_type_keine_zweck             42718 non-null  float64
#  80  wg_type_maenner                 42718 non-null  float64
#  81  wg_type_business                42718 non-null  float64
#  82  wg_type_wohnheim                42718 non-null  float64
#  83  wg_type_vegetarisch_vegan       42718 non-null  float64
#  84  wg_type_alleinerziehende        42718 non-null  float64
#  85  wg_type_funktionale             42718 non-null  float64
#  86  wg_type_berufstaetigen          42718 non-null  float64
#  87  wg_type_gemischte               42718 non-null  float64
#  88  wg_type_mit_kindern             42718 non-null  float64
#  89  wg_type_verbindung              42718 non-null  float64
#  90  wg_type_lgbtqia                 42718 non-null  float64
#  91  wg_type_senioren                42718 non-null  float64
#  92  wg_type_inklusive               42718 non-null  float64
#  93  wg_type_wg_neugruendung         42718 non-null  float64
#  94  internet_dsl                    42718 non-null  float64
#  95  internet_wlan                   42718 non-null  float64
#  96  internet_flatrate               42718 non-null  float64
# dtypes: float64(91), int64(1), object(5)
# memory usage: 31.6+ MB

# %%
df_zscored = df_zscored.dropna(axis=0)
# z-scoring columns
df_zscored = standardize_features(df_zscored, columns_to_zscore)

# Filter table if needed
df_city = df_zscored#[df_zscored['city'] == 'Berlin']
df_city.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [19], line 3
#       1 df_zscored = df_zscored.dropna(axis=0)
#       2 # z-scoring columns
# ----> 3 df_zscored = standardize_features(df_zscored, columns_to_zscore)
#       5 # Filter table if needed
#       6 df_city = df_zscored#[df_zscored['city'] == 'Berlin']
#
# NameError: name 'standardize_features' is not defined

# %%
sns.set_theme(style = "whitegrid", font_scale= 1)
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(25, 20))

data_corr = df_city.corr()
sns.heatmap(data_corr, cmap='coolwarm', 
            annot = False, 
            annot_kws={"size": 8},
            vmin=-0.5, vmax=0.5);

# %%
data_corr = df_city.corr()

corr_df = data_corr.unstack().reset_index() # Unstack correlation matrix 
corr_df.columns = ['feature_1','feature_2', 'correlation'] # rename columns
corr_df.sort_values(by="correlation",ascending=False, inplace=True) # sort by correlation
corr_df = corr_df[corr_df['feature_1'] != corr_df['feature_2']] # Remove self correlation
corr_df.head(30)

# %%
# Variation Inflation Factor (VIF) analysis
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
df = pd.DataFrame()

df["features"] = columns_to_zscore

df["vif_index"] = [vif(df_city[columns_to_zscore].values, i) for i in range(df_city[columns_to_zscore].shape[1])]

round(df.sort_values(by="vif_index", ascending = False),2)

# %%
# OLS model
formula = target + ' ~ ' + ' + '.join(selected_num_features) + ' + ' + ' + '.join(['C('+feat+')-1' for feat in selected_cat_features]) + '-1'

model_city = smf.ols(formula = formula, data=df_city).fit()
model_city.summary()

# %%
sns.set_theme(style = "whitegrid", font_scale= 1)
fig = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))

model_city.params[0:].plot(kind='barh');

# %%
y_pred = model_city.predict(df_city)
y_base = [np.mean(df_city['cold_rent_euros'])]*len(y_pred)
y_true = df_city['cold_rent_euros']

print(f'RMSE: {np.sqrt(((y_pred - y_true) ** 2).mean())}')
print(f'RMSE base model: {np.sqrt(((y_base - y_true) ** 2).mean())}')

n=len(df_city)
residuals = y_true - y_pred
residuals_base = y_true - y_base

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
sns.histplot(residuals, kde=True, edgecolor='w', ax=ax1)
sns.histplot(residuals_base, kde=True, edgecolor='w', ax=ax2)

# https://stats.stackexchange.com/questions/101274/how-to-interpret-a-qq-plot
sm.qqplot(model_city.resid, ax=ax3)
plt.tight_layout()
fig.show();

# %%
sns.scatterplot(x=model_city.predict(df_city), y=model_city.resid);

# %%
df = return_significative_coef(model_city).set_index('variable')
print(df)

sns.set_theme(style = "whitegrid", font_scale= 1)
fig = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))
df.coef.plot(kind='barh');

# %% [markdown]
# # Linear model Apartment

# %%
flathouse_df.info()

# %%
# define columns to work
features = [
    'km_to_centroid',
    'sin_degrees_to_centroid',
    'cos_degrees_to_centroid',
    
    'comfort_leisure_spots',
    'comfort_warehouse',
    'activities_education',
    'mobility_public_transport_bus',
    'activities_economic',
    'comfort_industrial',
    'activities_goverment',
    'social_life_eating',
    'comfort_comfort_spots',
    'social_life_culture',
    'activities_supermarket',
##     'activities_public_service',
    'social_life_community',
    'comfort_leisure_mass',
    'activities_educational',
    'mobility_street_secondary',
    'mobility_public_transport_rail',
    'activities_retail',
    'social_life_night_life',
    'comfort_green_natural',
    'comfort_railway',
    'mobility_bike_infraestructure',
##     'comfort_green_forests',
    'mobility_street_primary',
    'comfort_lakes',
##     'activities_health_regional',
    'activities_health_local',
    'comfort_green_space',
    'comfort_rivers',
    'activities_post',
    'comfort_green_parks',
    'comfort_street_motorway'
]

target = 'cold_rent_euros'

selected_num_features = [
    'size_sqm',
#             'days_available',
            'available_rooms',
#             'capacity',
#             'male_flatmates',
#             'female_flatmates',
#             'diverse_flatmates',
    
#             'cold_rent_euros',
#             'mandatory_costs_euros',
#             'extra_costs_euros',
            'transfer_costs_euros',
#             'deposit',

#             'building_floor',
#             'public_transport_distance',
#             'home_total_size',
            'furniture_numerical',
            'kitchen_numerical',
            'smoking_numerical',
    
#             'min_age_flatmates',
#             'max_age_flatmates',
    
#             'min_age_searched',
#             'max_age_searched',
    
#             'number_languages',
    
#             'sin_published_at',
#             'cos_published_at',
#             'sin_day_week_int',
#             'cos_day_week_int'
    
] + features
selected_cat_features = ['city',
                         'commercial_landlord',
            'rental_length_term',
#             'energy',
            'wg_possible',
            'building_type',
#             'shower_type',
#             'floor_type',
#             'heating',
#             'internet',
#             'parking',
                         
            'schufa_needed',
                         
            'extras_waschmaschine',
            'extras_spuelmaschine',
            'extras_terrasse',
            'extras_balkon',
            'extras_garten',
#             'extras_gartenmitbenutzung',
            'extras_keller',
            'extras_aufzug',
            'extras_haustiere',
            'extras_fahrradkeller',
            'extras_dachboden',
                         
#             'languages_deutsch',
#             'languages_englisch',
                         
#             'wg_type_studenten',
#             'wg_type_keine_zweck',
#             'wg_type_maenner',
#             'wg_type_business',
#             'wg_type_wohnheim',
#             'wg_type_vegetarisch_vegan',
#             'wg_type_alleinerziehende',
#             'wg_type_funktionale',
#             'wg_type_berufstaetigen',
#             'wg_type_gemischte',
#             'wg_type_mit_kindern',
#             'wg_type_verbindung',
#             'wg_type_lgbtqia',
#             'wg_type_senioren',
#             'wg_type_inklusive',
#             'wg_type_wg_neugruendung',
                         
            'tv_kabel',
            'tv_satellit',
                         
#             'gender_searched',
                         
#             'age_category_searched'
                        ]
all_columns = [target] + selected_num_features + selected_cat_features

columns_to_zscore = selected_num_features


# Filter dataframe for modelling
df_zscored = flathouse_df[all_columns#+['city']
                     ].copy()

df_zscored.info()

# %%
df_zscored = df_zscored.dropna(axis=0)
# z-scoring columns
df_zscored = standardize_features(df_zscored, columns_to_zscore)

# Filter table if needed
df_city = df_zscored#[df_zscored['city'] == 'Leipzig']
df_city.shape

# %%
sns.set_theme(style = "whitegrid", font_scale= 1)
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(15, 12.5))

sns.heatmap(df_city.corr(), cmap='coolwarm', 
            annot = False, 
            annot_kws={"size": 8},
            vmin=-0.5, vmax=0.5);

# %%
data_corr = df_city.corr()

corr_df = data_corr.unstack().reset_index() # Unstack correlation matrix 
corr_df.columns = ['feature_1','feature_2', 'correlation'] # rename columns
corr_df.sort_values(by="correlation",ascending=False, inplace=True) # sort by correlation
corr_df = corr_df[corr_df['feature_1'] != corr_df['feature_2']] # Remove self correlation
corr_df.head(30)

# %%
# Variation Inflation Factor (VIF) analysis
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
df = pd.DataFrame()

df["features"] = columns_to_zscore

df["vif_index"] = [vif(df_city[columns_to_zscore].values, i) for i in range(df_city[columns_to_zscore].shape[1])]

round(df.sort_values(by="vif_index", ascending = False),2)

# %%
# OLS model
formula = target + ' ~ ' + ' + '.join(selected_num_features) + ' + ' + ' + '.join(['C('+feat+')-1' for feat in selected_cat_features]) + '-1'

model_city = smf.ols(formula = formula, data=df_city).fit()
model_city.summary()

# %%
sns.set_theme(style = "whitegrid", font_scale= 1)
fig = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))

model_city.params[0:].plot(kind='barh');

# %%
y_pred = model_city.predict(df_city)
y_base = [np.mean(df_city['cold_rent_euros'])]*len(y_pred)
y_true = df_city['cold_rent_euros']

print(f'RMSE: {np.sqrt(((y_pred - y_true) ** 2).mean())}')
print(f'RMSE base model: {np.sqrt(((y_base - y_true) ** 2).mean())}')

n=len(df_city)
residuals = y_true - y_pred
residuals_base = y_true - y_base

fig, (ax1,ax2,ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
sns.histplot(residuals, kde=True, edgecolor='w', ax=ax1)
sns.histplot(residuals_base, kde=True, edgecolor='w', ax=ax2)

# https://stats.stackexchange.com/questions/101274/how-to-interpret-a-qq-plot
sm.qqplot(residuals, ax=ax3)

plt.tight_layout()
fig.show();

# %%
sns.scatterplot(x=y_pred, y=residuals);

# %%
df = return_significative_coef(model_city).set_index('variable')
print(df)

sns.set_theme(style = "whitegrid", font_scale= 1)
fig = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))
df.coef.plot(kind='barh');

# %% [markdown]
# # Linear model Single-room flats

# %%
singleroom_df.info()

# %%
# define columns to work
features = [
    'km_to_centroid',
    'sin_degrees_to_centroid',
    'cos_degrees_to_centroid',
    
    'comfort_leisure_spots',
    'comfort_warehouse',
    'activities_education',
    'mobility_public_transport_bus',
    'activities_economic',
    'comfort_industrial',
    'activities_goverment',
    'social_life_eating',
    'comfort_comfort_spots',
    'social_life_culture',
    'activities_supermarket',
##     'activities_public_service',
    'social_life_community',
    'comfort_leisure_mass',
    'activities_educational',
    'mobility_street_secondary',
    'mobility_public_transport_rail',
    'activities_retail',
    'social_life_night_life',
    'comfort_green_natural',
    'comfort_railway',
    'mobility_bike_infraestructure',
##     'comfort_green_forests',
    'mobility_street_primary',
    'comfort_lakes',
##     'activities_health_regional',
    'activities_health_local',
    'comfort_green_space',
    'comfort_rivers',
    'activities_post',
    'comfort_green_parks',
    'comfort_street_motorway'
]

target = 'cold_rent_euros'

selected_num_features = [
    'size_sqm',
#             'days_available',
#             'available_rooms',
#             'capacity',
#             'male_flatmates',
#             'female_flatmates',
#             'diverse_flatmates',
    
#             'cold_rent_euros',
#             'mandatory_costs_euros',
#             'extra_costs_euros',
            'transfer_costs_euros',
#             'deposit',

            'building_floor',
#             'public_transport_distance',
#             'home_total_size',
            'furniture_numerical',
            'kitchen_numerical',
#             'smoking_numerical',
    
#             'min_age_flatmates',
#             'max_age_flatmates',
    
#             'min_age_searched',
#             'max_age_searched',
    
#             'number_languages',
    
#             'sin_published_at',
#             'cos_published_at',
#             'sin_day_week_int',
#             'cos_day_week_int'
    
] + features
selected_cat_features = ['city',
                         'commercial_landlord',
            'rental_length_term',
#             'energy',
#             'wg_possible',
            'building_type',
#             'shower_type',
#             'floor_type',
#             'heating',
#             'internet',
#             'parking',
                         
            'schufa_needed',
                         
            'extras_waschmaschine',
            'extras_spuelmaschine',
            'extras_terrasse',
            'extras_balkon',
            'extras_garten',
#             'extras_gartenmitbenutzung',
            'extras_keller',
            'extras_aufzug',
            'extras_haustiere',
            'extras_fahrradkeller',
            'extras_dachboden',
                         
#             'languages_deutsch',
#             'languages_englisch',
                         
#             'wg_type_studenten',
#             'wg_type_keine_zweck',
#             'wg_type_maenner',
#             'wg_type_business',
#             'wg_type_wohnheim',
#             'wg_type_vegetarisch_vegan',
#             'wg_type_alleinerziehende',
#             'wg_type_funktionale',
#             'wg_type_berufstaetigen',
#             'wg_type_gemischte',
#             'wg_type_mit_kindern',
#             'wg_type_verbindung',
#             'wg_type_lgbtqia',
#             'wg_type_senioren',
#             'wg_type_inklusive',
#             'wg_type_wg_neugruendung',
                         
            'tv_kabel',
            'tv_satellit',
                         
            'gender_searched',
                         
            'age_category_searched'
                        ]
all_columns = [target] + selected_num_features + selected_cat_features

columns_to_zscore = selected_num_features


# Filter dataframe for modelling
df_zscored = singleroom_df[all_columns#+['city']
                     ].copy()

df_zscored.info()

# %%
df_zscored = df_zscored.dropna(axis=0)
# z-scoring columns
df_zscored = standardize_features(df_zscored, columns_to_zscore)

# Filter table if needed
df_city = df_zscored#[df_zscored['city'] == 'Leipzig']
df_city.shape

# %%
sns.set_theme(style = "whitegrid", font_scale= 1)
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(15, 12.5))

sns.heatmap(df_city.corr(), cmap='coolwarm', 
            annot = False, 
            annot_kws={"size": 8},
            vmin=-0.5, vmax=0.5);

# %%
data_corr = df_city.corr()

corr_df = data_corr.unstack().reset_index() # Unstack correlation matrix 
corr_df.columns = ['feature_1','feature_2', 'correlation'] # rename columns
corr_df.sort_values(by="correlation",ascending=False, inplace=True) # sort by correlation
corr_df = corr_df[corr_df['feature_1'] != corr_df['feature_2']] # Remove self correlation
corr_df.head(30)

# %%
# Variation Inflation Factor (VIF) analysis
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
df = pd.DataFrame()

df["features"] = columns_to_zscore

df["vif_index"] = [vif(df_city[columns_to_zscore].values, i) for i in range(df_city[columns_to_zscore].shape[1])]

round(df.sort_values(by="vif_index", ascending = False),2)

# %%
# OLS model
formula = target + ' ~ ' + ' + '.join(selected_num_features) + ' + ' + ' + '.join(['C('+feat+')-1' for feat in selected_cat_features]) + '-1'

model_city = smf.ols(formula = formula, data=df_city).fit()
model_city.summary()

# %%
sns.set_theme(style = "whitegrid", font_scale= 1)
fig = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))

model_city.params[0:].plot(kind='barh');

# %%
y_pred = model_city.predict(df_city)
y_base = [np.mean(df_city['cold_rent_euros'])]*len(y_pred)
y_true = df_city['cold_rent_euros']

print(f'RMSE: {np.sqrt(((y_pred - y_true) ** 2).mean())}')
print(f'RMSE base model: {np.sqrt(((y_base - y_true) ** 2).mean())}')

n=len(df_city)
residuals = y_true - y_pred
residuals_base = y_true - y_base

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
sns.histplot(residuals, kde=True, edgecolor='w', ax=ax1)
sns.histplot(residuals_base, kde=True, edgecolor='w', ax=ax2)

# https://stats.stackexchange.com/questions/101274/how-to-interpret-a-qq-plot
sm.qqplot(model_city.resid, ax=ax3)
plt.tight_layout()
fig.show();

# %%
sns.scatterplot(x=model_city.predict(df_city), y=model_city.resid);

# %%
df = return_significative_coef(model_city).set_index('variable')
print(df)

sns.set_theme(style = "whitegrid", font_scale= 1)
fig = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))
df.coef.plot(kind='barh');
